# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/om/OneDrive/Desktop/supermarket.csv")

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull().count()
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df = df.drop(['Tax 5%','Time','cogs'],axis = True)

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity     Total       Date  \
# 0       Health and beauty       74.69         7  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  634.3785   2/8/2019
#
#        Payment  gross margin percentage  gross income  Rating
# 0      Ewallet                 4.761905       26.1415     9.1
# 1         Cash                 4.761905        3.8200     9.6
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date']
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Total                             float64
# Date                       datetime64[ns]
# Payment                            object
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df.set_index('Date',inplace =True)

# %%
df.head(5)
# Out:
#              Invoice ID Branch       City Customer type  Gender  \
# Date
# 2019-01-05  750-67-8428      A     Yangon        Member  Female
# 2019-03-08  226-31-3081      C  Naypyitaw        Normal  Female
# 2019-03-03  631-41-3108      A     Yangon        Normal    Male
# 2019-01-27  123-19-1176      A     Yangon        Member    Male
# 2019-02-08  373-73-7910      A     Yangon        Normal    Male
#
#                       Product line  Unit price  Quantity     Total  \
# Date
# 2019-01-05       Health and beauty       74.69         7  548.9715
# 2019-03-08  Electronic accessories       15.28         5   80.2200
# 2019-03-03      Home and lifestyle       46.33         7  340.5255
# 2019-01-27       Health and beauty       58.22         8  489.0480
# 2019-02-08       Sports and travel       86.31         7  634.3785
#
#                 Payment  gross margin percentage  gross income  Rating
# Date
# 2019-01-05      Ewallet                 4.761905       26.1415     9.1
# ...

# %%
df.corr()
# Out:
#                          Unit price  Quantity     Total  \
# Unit price                 1.000000  0.010778  0.633962
# Quantity                   0.010778  1.000000  0.705510
# Total                      0.633962  0.705510  1.000000
# gross margin percentage         NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000
# Rating                    -0.008778 -0.015815 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# Total                                        NaN      1.000000 -0.036442
# gross margin percentage                      NaN           NaN       NaN
# gross income                                 NaN      1.000000 -0.036442
# Rating                                       NaN     -0.036442  1.000000

# %%
sns.heatmap(np.round(df.corr(),2),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize=(12,12))
plt.show()

# %%
sns.pairplot(df)

# %%
sns.countplot(x = 'Gender',data = df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = 'Payment',data = df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
sns.countplot(x = 'Product line',data = df)
# Out:
# <AxesSubplot:xlabel='Product line', ylabel='count'>

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.countplot(x = 'Customer type',data = df)
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='count'>

# %%
sns.countplot(x = 'Branch',data = df)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
sns.catplot(x='Product line',y='Unit price',data=df, jitter=True, 
              hue='Gender', dodge=True,aspect=2)
plt.show()

# %%
sns.countplot(y='Product line',hue='Gender',data = df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Product line'>

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
sns.swarmplot(x='City',y='Unit price',data=df,split=True)
# Out:
# C:\Users\om\anaconda3\lib\site-packages\seaborn\categorical.py:3002: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='City', ylabel='Unit price'>

# %%
sns.countplot(y='Product line',hue='City',data = df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Product line'>

# %%
sns.countplot(y='Product line',hue='Payment',data = df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Product line'>

# %%
sns.countplot(y='Branch',hue='Payment',data = df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Branch'>

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.kdeplot(df['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
# !pip install wordcloud

# %%
import os
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
plt.subplots(figsize=(20,8))
wordcloud = WordCloud(background_color='White',width=1920,height=1080).generate(" ".join(df['Product line']))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
THANK YOU!!!
